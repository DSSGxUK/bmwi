# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/AloQuote_wide.csv', index_col=0)
df.shape
# Out:
# (401, 169)

# %%
df
# Out:
#        2007-05-31  2007-06-30  2007-07-31  2007-08-31  2007-09-30  2007-10-31  \
# 1001         12.7        12.2        12.5        12.3        11.7        11.2
# 1002         12.4        12.1        12.5        12.8        12.1        11.7
# 1003         12.8        12.7        12.9        12.9        12.7        12.4
# 1004         11.1        11.2        11.6        11.5        10.9        10.9
# 1051          9.9         9.5         9.7         9.7         9.0         8.8
# ...           ...         ...         ...         ...         ...         ...
# 16073        13.1        12.6        12.2        12.1        11.3        11.0
# 16074        11.2        10.6        10.3        10.4        10.1         9.8
# 16075        10.9         9.9        10.0        10.0         9.3         9.1
# 16076        13.1        12.5        12.5        12.5        11.7        11.2
# 16077        18.1        17.3        17.1        17.3        16.9        16.3
#
# ...

# %%
df[df.columns[10:20]]
# Out:
#        2008-03-31  2008-04-30  2008-05-31  2008-06-30  2008-07-31  2008-08-31  \
# 1001         11.4        11.4        11.4        11.0        11.4        11.8
# 1002         11.9        11.8        11.6        11.1        11.3        11.5
# 1003         12.6        12.5        12.4        12.1        12.3        12.3
# 1004         10.9        11.1        10.8        10.4        10.7        11.0
# 1051         10.2         9.6         9.3         9.0         9.4         9.6
# ...           ...         ...         ...         ...         ...         ...
# 16073        12.3        11.8        11.6        10.9        10.5        10.2
# 16074        10.8         9.8         9.1         8.4         8.3         8.3
# 16075        11.0        10.3         9.7         9.1         9.0         8.9
# 16076        12.4        11.6        11.0        10.5        11.2        11.1
# 16077        17.4        16.7        16.1        15.6        15.8        15.8
#
# ...
